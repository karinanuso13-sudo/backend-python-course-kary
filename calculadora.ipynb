# %%
my_variable =35
def my_function_1():
    my_variable =13
    print("my_function_1 - el valor de my_variable es : " , my_variable)

def my_function_2():
    my_variable =15
    print ("my_function_2 - el valor de my_variable es : " , my_variable)
    
def my_function_3():
    print ("my_function_2 - el valor de my_variable es : " , my_variable)

# %%
my_function_1()
# Out:
# my_function_1 - el valor de my_variable es :  13

# %%
my_function_2()
# Out:
# my_function_2 - el valor de my_variable es :  15

# %%
my_function_3()
# Out:
# my_function_2 - el valor de my_variable es :  35
