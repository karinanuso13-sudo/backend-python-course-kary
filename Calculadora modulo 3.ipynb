# %%
print("Operaciones: +  -  *  /  **")
op = input("Selecciona la operación: ")

# ------------------ LISTA ------------------
entrada_lista = input("Ingresa una lista (ejemplo: [1,2,3]): ")

try:
    lista = eval(entrada_lista)
    if type(lista) != list:
        print("Entrada inválida: eso no es una lista")
        raise SystemExit
except:
    print("Entrada inválida")
    raise SystemExit

# ------------------ SET ------------------
entrada_set = input("Ingresa un set (ejemplo: {1,2,3}): ")

try:
    conjunto = eval(entrada_set)
    if type(conjunto) != set:
        print("Entrada inválida: eso no es un set")
        raise SystemExit
except:
    print("Entrada inválida")
    raise SystemExit

# ------------------ DICCIONARIO ------------------
entrada_dicc = input('Ingresa un diccionario de 5 números ({"a":1,"b":2,"c":3,"d":4,"e":5}): ')

try:
    dicc = eval(entrada_dicc)
    if type(dicc) != dict:
        print("Entrada inválida: eso no es un diccionario")
        raise SystemExit
    if len(dicc) != 5:
        print("Tamaño inválido: el diccionario debe tener 5 elementos")
        raise SystemExit
except:
    print("Entrada inválida")
    raise SystemExit


# ------------------ VALIDACIÓN DE TAMAÑOS ------------------
conjunto = list(conjunto)  # convertir set a lista

if len(lista) != len(conjunto):
    print("Tamaño inválido: lista y set deben tener el mismo tamaño para operar.")
    raise SystemExit


# ------------------ HACER LA OPERACIÓN ------------------
resultado = []

for i in range(len(lista)):
    a = lista[i]
    b = conjunto[i]

    if op == "+":
        resultado.append(a + b)
    elif op == "-":
        resultado.append(a - b)
    elif op == "*":
        resultado.append(a * b)
    elif op == "/":
        if b == 0:
            resultado.append("Error: división por cero")
        else:
            resultado.append(a / b)
    elif op == "**":
        resultado.append(a ** b)
    else:
        print("Operación inválida")
        raise SystemExit


# ------------------ MOSTRAR TODO AL FINAL ------------------
print("\n--- RESULTADOS ---")
print("Lista ingresada:", lista)
print("Set ingresado:", conjunto)
print("Diccionario ingresado:", dicc)
print("Operación solicitada:", op)
print("Resultado operación lista vs set:", resultado)
# Out:
# Operaciones: +  -  *  /  **
# Selecciona la operación:  +
# Ingresa una lista (ejemplo: [1,2,3]):  [1 2 3 4 5]
# Entrada inválida
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# Cell In[58], line 8
#       7 try:
# ----> 8     lista = eval(entrada_lista)
#       9     if type(lista) != list:
#
# SyntaxError: invalid syntax. Perhaps you forgot a comma? (<string>, line 1)
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[58], line 14
#      13     print("Entrada inválida")
# ---> 14     raise SystemExit
#      16 # ------------------ SET ------------------
#
# SystemExit:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ...
