# %%
import pokebase as pb
import requests

pokemon_to_search = input ("ingresa el nombre de un pokemon\n\n")
data = pb.pokemon(pokemon_to_search).__dict__
id_ = data.get ('id_')
name= data.get('name')
height = data.get ('height')
weight = data.get ('weight')

print("ID: ", id_)
print("Nombre: ",name)
print("Altura: ", height)
print("Peso: ", weight)

url = "https://pokeapi.co/api/v2/characteristic/{id}/".format(id=id_)
response = requests.get(url)
for description_dict in response.json().get ("descriptions"):
    if description_dict.get("language", {}).get("name") == "es":
        description = description_dict.get("description")
        print ("Description: ", description)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pokebase as pb
#       2 import requests
#       4 pokemon_to_search = input ("ingresa el nombre de un pokemon\n\n")
#
# ModuleNotFoundError: No module named 'pokebase'

# %%
# !pip install pokebase
# Out:
# Requirement already satisfied: pokebase in c:\users\luzso\anaconda3\lib\site-packages (1.4.1)
# Requirement already satisfied: requests in c:\users\luzso\anaconda3\lib\site-packages (from pokebase) (2.32.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\luzso\anaconda3\lib\site-packages (from requests->pokebase) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\luzso\anaconda3\lib\site-packages (from requests->pokebase) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\luzso\anaconda3\lib\site-packages (from requests->pokebase) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\luzso\anaconda3\lib\site-packages (from requests->pokebase) (2025.11.12)

# %%
import pokebase as pb
import requests

pokemon_to_search = input ("ingresa el nombre de un pokemon\n\n")
data = pb.pokemon(pokemon_to_search).__dict__
id_ = data.get ('id')
name= data.get('name')
height = data.get ('height')
weight = data.get ('weight')

print("ID: ", id_)
print("Nombre: ",name)
print("Altura: ", height)
print("Peso: ", weight)

url = "https://pokeapi.co/api/v2/characteristic/{id}/".format(id=id_)
response = requests.get(url)
for description_dict in response.json().get ("descriptions"):
    if description_dict.get("language", {}).get("name") == "es":
        description = description_dict.get("description")
        print ("Description: ", description)
# Out:
# ingresa el nombre de un pokemon
#
#  pikachu
# ID:  25
# Nombre:  pikachu
# Altura:  4
# Peso:  60
# Description:  Le gusta relajarse
