# %%
print("Calculadora (+, -, *, /)")
operación = input("Ingresa el operador (+, -, *, /, **,): ")
my_list = input("Ingresa 5 numeros separados por comas entre []: ")
   #lista
lista= eval(my_list)
print (lista)
print (type(lista))
if type(lista) != list:
        print("Entrada inválida: no es una lista")
    #set
my_set = input("Ingresa 5 numeros separados por comas entre {}: ")
set1= eval(my_set)
print (set1)
print (type(set1))
if type(set1) != set:
    print("Entrada inválida: no es un set")
if type (set1) != 5:
        print("Entrada inválida no contiene 5 elementos")
    
    #dictionary
my_dictionary = input("Ingresa 5 numeros separados por comas entre {'a':num1,'b':num2,'c':num3,'d':num4, 'e':num5,}: ")
dictionary = eval (my_dictionary)
print (dictionary)
print (type(dictionary))
if type(dictionary) != dict: 
        print("Entrada inválida: no es un diccionario")
if type (dictionary) != 5:
      print("Entrada inválida: no contiene 5 elementos")

    #convertir set y diccionario a listas
set1 = list(set1)
dictionary = list (dictionary.values())
resultado = []

for i in range (5):
    a = lista [i]
    b = set1 [i]
    c = dictionary [i]

if operación == "+":
    resultado. append (a+b+c)
if operación == "-":
    resultado. append (a-b-c)
if operación == "/":
    if b==0 or c==0:
        print ("error  de división entre cero.")
        exit()
    resultado. append (a/b/c)
if operación == "*":
    resultado. append (a*b*c)
if operación == "**":
    resultado. append (a**b**c)
else :
    print ("operación invalida.")
    exit ()

#resultados
print (" Resultado final")
print ("lista ingresada :", lista)
print ("set ingresado :", set1)
print ("diccionario ingresado :", dictionary)

print ("operación:", operación)
print ("resultado:", resultado)
