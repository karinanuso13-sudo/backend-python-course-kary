# %%
menos_descuento = lambda x:x - 300
my_cart = [500, 800, 950, 1300]
result = map (menos_descuento, my_cart)
list (result)
# Out:
# [200, 500, 650, 1000]

# %%
def compra(cart):
    def calculate_total():
        total = 0

        for item in cart:
            total +=item["precio"]
        return total

    total = calculate_total()

    if total > 1000:
        total_compra = total * 0.70

    return total
cart = [
    {"product": "Shoes", "precio": 1300},
    {"product": "T-shirt", "precio": 800}
]

final_price = compra(cart)
print(final_price)
# Out:
# 2100
