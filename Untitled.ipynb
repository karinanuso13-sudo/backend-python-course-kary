# %%
num_1= 13
num_2= 20
print ("num_1 antes de la operación : " , num_1)
num_1 += num_2 
print ("nume_1 despues de la operación : ", num_1)
# Out:
# num_1 antes de la operación :  13
# nume_1 despues de la operación :  33

# %%
num_1= 13
num_2= 20
print ("num_1 antes de la operación : " , num_1)
num_1 -= num_2 
print ("nume_1 despues de la operación : ", num_1)
# Out:
# num_1 antes de la operación :  13
# nume_1 despues de la operación :  -7

# %%
num_1= 13
num_2= 20
print ("num_1 <= num_2 and num_1 != num_2" ,num_1 <= num_2 and num_1 != num_2)
# Out:
# num_1 <= num_2 and num_1 != num_2 True

# %%
num_1= 13
num_2= 20
print ("num_1 <= num_2 and num_1 != num_2" ,num_1 <= num_2 or num_1 != num_2)
# Out:
# num_1 <= num_2 and num_1 != num_2 True

# %%
num_1= 13
num_2= 20
print ("num_1 >= num_2 and num_1 != num_2" ,num_1 <= num_2 or num_1 != num_2)
# Out:
# num_1 >= num_2 and num_1 != num_2 True

# %%
num_1= 13
num_2= 20
print ("num_1 >= num_2 and num_1 != num_2" ,num_1 >= num_2 or num_1 == num_2)
# Out:
# num_1 >= num_2 and num_1 != num_2 False

# %%
num_1= 13
num_2= 20
print ("num_1 >= num_2 and num_1 != num_2" ,num_1 >= num_2 or num_1 == num_2 or num_1 >= 10)
# Out:
# num_1 >= num_2 and num_1 != num_2 True

# %%
num_1= 13
num_2= 20
#false
print (" not num_1 >= num_2 " ,not num_1 >= num_2)
# Out:
#  not num_1 >= num_2  True

# %%
num_1= 13
num_2= 20
#true
print (" not num_1 <= num_2 " ,not num_1 <= num_2)
# Out:
#  not num_1 <= num_2  False

# %%
my_string = "curso Backend python"
print (" 'b' in my_string" , 'b' in my_string)
# Out:
#  'b' in my_string False

# %%
my_string = "curso Backend python"
print (" 'B' in my_string" , 'B' in my_string)
# Out:
#  'B' in my_string True
