# %%
import requests
print ("Lista de Reproducción\n")

#Referencia: https://www.deezer.com/en/channels/explore

print ("Ingresa tu artista o genero de tu preferencia")
print ("Ejemplo: 'Rock', y obtendras un playlist de canciones o artistas que incluyan la palabra rock")

word_to_search = input ()
url= "https://deezerdevs-deezer.p.rapidapi.com/search"
querystring = {"q":word_to_search}
headers = {
    "X-RapidAPI-Key":"3ed98f551fmshe4e6260228c4eadp13db17jsn8c893e1194da",
    "X-RapidAPI-Host":"deezerdevs-deezer.p.rapidapi.com"
}
response = requests.request("GET", url, headers=headers, params = querystring).json()
my_list = [
    {
        "Artista": element["artist"]["name"],
        "Canción": element["title"]
    }
    for element in response["data"]
]

for item in my_list:
    print(item)
# Out:
# Lista de Reproducción
#
# Ingresa tu artista o genero de tu preferencia
# Ejemplo: 'Rock', y obtendras un playlist de canciones o artistas que incluyan la palabra rock
#  Blink 182
# {'Artista': 'blink-182', 'Canción': 'All The Small Things'}
# {'Artista': 'blink-182', 'Canción': 'I Miss You'}
# {'Artista': 'blink-182', 'Canción': 'First Date'}
# {'Artista': 'blink-182', 'Canción': "What's My Age Again?"}
# {'Artista': 'blink-182', 'Canción': "Adam's Song"}
# {'Artista': 'blink-182', 'Canción': 'Feeling This'}
# {'Artista': 'blink-182', 'Canción': 'The Rock Show'}
# {'Artista': 'blink-182', 'Canción': "She's Out Of Her Mind"}
# {'Artista': 'blink-182', 'Canción': 'Stay Together For The Kids'}
# {'Artista': 'blink-182', 'Canción': 'Anthem Part Two'}
# {'Artista': 'blink-182', 'Canción': 'Always'}
# {'Artista': 'blink-182', 'Canción': 'Dammit'}
# {'Artista': 'blink-182', 'Canción': 'Emo'}
# {'Artista': 'blink-182', 'Canción': 'ONE MORE TIME'}
# {'Artista': 'blink-182', 'Canción': 'Every Time I Look For You'}
# {'Artista': 'blink-182', 'Canción': 'Darkside'}
# {'Artista': 'blink-182', 'Canción': 'Mutt'}
# {'Artista': 'blink-182', 'Canción': 'Aliens Exist'}
# {'Artista': 'blink-182', 'Canción': 'Apple Shampoo'}
# {'Artista': 'blink-182', 'Canción': 'Bored To Death'}
# {'Artista': 'blink-182', 'Canción': 'Dumpweed'}
# {'Artista': 'blink-182', 'Canción': 'Happy Days'}
# {'Artista': 'blink-182', 'Canción': 'ANTHEM PART 3'}
# {'Artista': 'blink-182', 'Canción': 'EDGING'}
# {'Artista': 'blink-182', 'Canción': 'Online Songs'}
