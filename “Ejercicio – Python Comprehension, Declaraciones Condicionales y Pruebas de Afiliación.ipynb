# %%
import requests
print ("Lista de Reproducción\n")

#Referencia: https://www.deezer.com/en/channels/explore

print ("Ingresa la palabra que te gustaria")
print ("Ejemplo: 'Rock', y obtendras un playlist de canciones o artistas que incluyan la palabra rock")

word_to_search = input ()
url= "https://deezerdevs-deezer.p.rapidapi.com/search"
querystring = {"q":word_to_search}
headers = {
    "X-RapidAPI-Key":"3ed98f551fmshe4e6260228c4eadp13db17jsn8c893e1194da",
    "X-RapidAPI-Host":"deezerdevs-deezer.p.rapidapi.com"
}
response = requests.request("GET", url, headers=headers, params = querystring).json()
my_list = [
    {
        "artista": element["artist"]["name"],
        "canción": element["title"]
    }
    for element in response["data"]
]

for item in my_list:
    print(item)
# Out:
# Lista de Reproducción
#
# Ingresa la palabra que te gustaria
# Ejemplo: 'Rock', y obtendras un playlist de canciones o artistas que incluyan la palabra rock
#  rock
# {'artista': 'Brenda Lee', 'canción': "Rockin' Around The Christmas Tree"}
# {'artista': 'Post Malone', 'canción': 'rockstar'}
# {'artista': 'Justin Timberlake', 'canción': 'Rock Your Body'}
# {'artista': 'Stepz', 'canción': 'Rock'}
# {'artista': 'Oliver Malcolm', 'canción': 'Rock & Roll'}
# {'artista': 'Boston', 'canción': 'Rock & Roll Band'}
# {'artista': 'The Subways', 'canción': 'Rock & Roll Queen'}
# {'artista': 'Bob Sinclar', 'canción': 'Rock This Party (Everybody Dance Now)'}
# {'artista': 'R3HAB', 'canción': 'Rock My Body'}
# {'artista': 'Lacrim', 'canción': 'Rock (feat. Baby Gang)'}
# {'artista': 'The Velvet Underground', 'canción': 'Rock & Roll (Full Length Version; 2015 Remaster)'}
# {'artista': 'Forrest Frank', 'canción': 'THE ROCK'}
# {'artista': 'ITZY', 'canción': 'ROCK & ROLL'}
# {'artista': 'Stray Kids', 'canción': 'ROCK'}
# {'artista': 'Eric Hutchinson', 'canción': 'Rock & Roll'}
# {'artista': 'BadKarma', 'canción': 'rock (slowed + reverb)'}
# {'artista': 'B.J. Thomas', 'canción': 'Rock & Roll Lullaby'}
# {'artista': 'Dennis Quin', 'canción': 'Rock & Rule'}
# {'artista': 'The City of Prague Philharmonic Orchestra', 'canción': 'The Rock (From "The Rock")'}
# {'artista': 'Matthew E. White', 'canción': 'Rock & Roll Is Cold'}
# {'artista': 'Pleymo', 'canción': 'Rock'}
# {'artista': 'Moura Dj', 'canción': 'ROCK'}
# {'artista': "C'typeencostume", 'canción': '_________ Rock ___ (2/3)'}
# {'artista': 'The Joker & the Thief', 'canción': 'Rock & Roll, Part 2'}
# {'artista': 'Plies', 'canción': 'Rock'}
