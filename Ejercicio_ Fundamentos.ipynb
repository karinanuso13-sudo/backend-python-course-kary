# %%
num1 = int(input("Ingresa un número: "))
print (num1)
print (type(num1))


num2 = float(input("Ingresa un número decimal: "))
print (num2)
print (type(num2))

num3 = (input("Ingresa un número : "))
print (num3)
print (type(num3))
# Out:
# Ingresa un número:  13
# 13
# <class 'int'>
# Ingresa un número decimal:  13.5
# 13.5
# <class 'float'>
# Ingresa un número :  13
# 13
# <class 'str'>
